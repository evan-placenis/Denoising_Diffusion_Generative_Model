# %% [markdown]
# <a href="https://colab.research.google.com/github/evan-placenis/Denoising_Diffusion_Generative_Model/blob/main/Denoising_Diffusion_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
from google.colab import drive
drive.mount('/content/drive')
! mkdir ~/.kaggle
# !cp /content/drive/MyDrive/KaggleAPI/kaggle.json ~/.kaggle/kaggle.json
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Mounted at /content/drive

# %%
! kaggle datasets download nunenuh/pytorch-challange-flower-dataset
# Out:
# Downloading pytorch-challange-flower-dataset.zip to /content
#  99% 328M/330M [00:17<00:00, 22.9MB/s]
# 100% 330M/330M [00:17<00:00, 19.7MB/s]

# %%
# !unzip /content/pytorch-challange-flower-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/train/48/image_04685.jpg
#   inflating: dataset/train/48/image_04686.jpg
#   inflating: dataset/train/48/image_04689.jpg
#   inflating: dataset/train/48/image_04692.jpg
#   inflating: dataset/train/48/image_04694.jpg
#   inflating: dataset/train/48/image_04695.jpg
#   inflating: dataset/train/49/image_06198.jpg
#   inflating: dataset/train/49/image_06199.jpg
#   inflating: dataset/train/49/image_06200.jpg
#   inflating: dataset/train/49/image_06201.jpg
#   inflating: dataset/train/49/image_06203.jpg
#   inflating: dataset/train/49/image_06204.jpg
#   inflating: dataset/train/49/image_06205.jpg
#   inflating: dataset/train/49/image_06206.jpg
#   inflating: dataset/train/49/image_06207.jpg
#   inflating: dataset/train/49/image_06208.jpg
#   inflating: dataset/train/49/image_06211.jpg
#   inflating: dataset/train/49/image_06212.jpg
#   inflating: dataset/train/49/image_06214.jpg
#   inflating: dataset/train/49/image_06217.jpg
#   inflating: dataset/train/49/image_06218.jpg
#   inflating: dataset/train/49/image_06219.jpg
#   inflating: dataset/train/49/image_06220.jpg
#   inflating: dataset/train/49/image_06221.jpg
#   inflating: dataset/train/49/image_06223.jpg
#   inflating: dataset/train/49/image_06224.jpg
#   inflating: dataset/train/49/image_06225.jpg
#   inflating: dataset/train/49/image_06226.jpg
#   inflating: dataset/train/49/image_06227.jpg
#   inflating: dataset/train/49/image_06229.jpg
#   inflating: dataset/train/49/image_06231.jpg
#   inflating: dataset/train/49/image_06232.jpg
#   inflating: dataset/train/49/image_06233.jpg
#   inflating: dataset/train/49/image_06234.jpg
#   inflating: dataset/train/49/image_06236.jpg
#   inflating: dataset/train/49/image_06237.jpg
#   inflating: dataset/train/49/image_06238.jpg
#   inflating: dataset/train/49/image_06239.jpg
#   inflating: dataset/train/49/image_06241.jpg
#   inflating: dataset/train/49/image_06242.jpg
#   inflating: dataset/train/49/image_06243.jpg
#   inflating: dataset/train/49/image_06244.jpg
#   inflating: dataset/train/49/image_06245.jpg
#   inflating: dataset/train/49/image_06246.jpg
#   inflating: dataset/train/5/image_05147.jpg
#   inflating: dataset/train/5/image_05148.jpg
#   inflating: dataset/train/5/image_05149.jpg
#   inflating: dataset/train/5/image_05150.jpg
#   inflating: dataset/train/5/image_05151.jpg
#   inflating: dataset/train/5/image_05152.jpg
#   inflating: dataset/train/5/image_05153.jpg
#   inflating: dataset/train/5/image_05154.jpg
#   inflating: dataset/train/5/image_05155.jpg
#   inflating: dataset/train/5/image_05156.jpg
#   inflating: dataset/train/52/image_04179.jpg
#   inflating: dataset/train/52/image_04180.jpg
#   inflating: dataset/train/52/image_04183.jpg
#   inflating: dataset/train/52/image_04184.jpg
#   inflating: dataset/train/52/image_04185.jpg
#   inflating: dataset/train/52/image_04186.jpg
#   inflating: dataset/train/52/image_04187.jpg
#   inflating: dataset/train/52/image_04188.jpg
#   inflating: dataset/train/52/image_04189.jpg
#   inflating: dataset/train/52/image_04190.jpg
#   inflating: dataset/train/52/image_04192.jpg
#   inflating: dataset/train/52/image_04193.jpg
#   inflating: dataset/train/52/image_04194.jpg
#   inflating: dataset/train/52/image_04195.jpg
#   inflating: dataset/train/52/image_04196.jpg
#   inflating: dataset/train/52/image_04197.jpg
#   inflating: dataset/train/52/image_04198.jpg
#   inflating: dataset/train/52/image_04199.jpg
#   inflating: dataset/train/52/image_04201.jpg
#   inflating: dataset/train/52/image_04202.jpg
#   inflating: dataset/train/52/image_04203.jpg
#   inflating: dataset/train/52/image_04204.jpg
#   inflating: dataset/train/52/image_04205.jpg
#   inflating: dataset/train/52/image_04206.jpg
#   inflating: dataset/train/52/image_04208.jpg
#   inflating: dataset/train/52/image_04209.jpg
#   inflating: dataset/train/52/image_04210.jpg
#   inflating: dataset/train/52/image_04211.jpg
#   inflating: dataset/train/52/image_04212.jpg
#   inflating: dataset/train/52/image_04213.jpg
#   inflating: dataset/train/52/image_04214.jpg
#   inflating: dataset/train/52/image_04216.jpg
#   inflating: dataset/train/52/image_04217.jpg
#   inflating: dataset/train/52/image_04218.jpg
#   inflating: dataset/train/52/image_04219.jpg
#   inflating: dataset/train/52/image_04220.jpg
#   inflating: dataset/train/52/image_04222.jpg
#   inflating: dataset/train/52/image_04223.jpg
#   inflating: dataset/train/52/image_04224.jpg
#   inflating: dataset/train/52/image_04226.jpg
#   inflating: dataset/train/52/image_04227.jpg
#   inflating: dataset/train/52/image_04228.jpg
#   inflating: dataset/train/52/image_04229.jpg
#   inflating: dataset/train/52/image_04230.jpg
#   inflating: dataset/train/52/image_04231.jpg
#   inflating: dataset/train/52/image_04232.jpg
#   inflating: dataset/train/52/image_04233.jpg
#   inflating: dataset/train/52/image_04234.jpg
#   inflating: dataset/train/52/image_04236.jpg
#   inflating: dataset/train/52/image_04237.jpg
#   inflating: dataset/train/52/image_04239.jpg
#   inflating: dataset/train/52/image_04241.jpg
#   inflating: dataset/train/52/image_04242.jpg
#   inflating: dataset/train/52/image_04243.jpg
#   inflating: dataset/train/53/image_03641.jpg
#   inflating: dataset/train/53/image_03642.jpg
#   inflating: dataset/train/53/image_03643.jpg
#   inflating: dataset/train/53/image_03644.jpg
#   inflating: dataset/train/53/image_03646.jpg
#   inflating: dataset/train/53/image_03647.jpg
#   inflating: dataset/train/53/image_03648.jpg
#   inflating: dataset/train/53/image_03650.jpg
#   inflating: dataset/train/53/image_03651.jpg
#   inflating: dataset/train/53/image_03657.jpg
#   inflating: dataset/train/53/image_03658.jpg
#   inflating: dataset/train/53/image_03659.jpg
#   inflating: dataset/train/53/image_03660.jpg
#   inflating: dataset/train/58/image_02683.jpg
#   inflating: dataset/train/58/image_02684.jpg
#   inflating: dataset/train/58/image_02685.jpg
#   inflating: dataset/train/58/image_02686.jpg
#   inflating: dataset/train/58/image_02688.jpg
#   inflating: dataset/train/58/image_02689.jpg
#   inflating: dataset/train/58/image_02692.jpg
#   inflating: dataset/train/58/image_02693.jpg
#   inflating: dataset/train/58/image_02696.jpg
#   inflating: dataset/train/58/image_02697.jpg
#   inflating: dataset/train/58/image_02698.jpg
#   inflating: dataset/train/58/image_02699.jpg
#   inflating: dataset/train/58/image_02701.jpg
#   inflating: dataset/train/58/image_02702.jpg
#   inflating: dataset/train/58/image_02703.jpg
#   inflating: dataset/train/58/image_02704.jpg
#   inflating: dataset/train/58/image_02706.jpg
#   inflating: dataset/train/58/image_02707.jpg
#   inflating: dataset/train/58/image_02708.jpg
#   inflating: dataset/train/58/image_02709.jpg
#   inflating: dataset/train/58/image_02710.jpg
#   inflating: dataset/train/58/image_02711.jpg
#   inflating: dataset/train/58/image_02712.jpg
#   inflating: dataset/train/58/image_02713.jpg
#   inflating: dataset/train/58/image_02714.jpg
#   inflating: dataset/train/58/image_02715.jpg
#   inflating: dataset/train/58/image_02716.jpg
#   inflating: dataset/train/58/image_02717.jpg
#   inflating: dataset/train/58/image_02718.jpg
#   inflating: dataset/train/58/image_02720.jpg
#   inflating: dataset/train/58/image_02723.jpg
#   inflating: dataset/train/58/image_02724.jpg
#   inflating: dataset/train/58/image_02725.jpg
#   inflating: dataset/train/58/image_02727.jpg
#   inflating: dataset/train/58/image_02728.jpg
#   inflating: dataset/train/58/image_02729.jpg
#   inflating: dataset/train/58/image_02730.jpg
#   inflating: dataset/train/58/image_02731.jpg
#   inflating: dataset/train/58/image_02732.jpg
#   inflating: dataset/train/58/image_02733.jpg
#   inflating: dataset/train/58/image_02735.jpg
#   inflating: dataset/train/58/image_02736.jpg
#   inflating: dataset/train/58/image_02739.jpg
#   inflating: dataset/train/58/image_02740.jpg
#   inflating: dataset/train/58/image_02744.jpg
#   inflating: dataset/train/58/image_02745.jpg
#   inflating: dataset/train/58/image_02746.jpg
#   inflating: dataset/train/58/image_02747.jpg
#   inflating: dataset/train/58/image_02748.jpg
#   inflating: dataset/train/58/image_02749.jpg
#   inflating: dataset/train/58/image_02750.jpg
#   inflating: dataset/train/58/image_02751.jpg
#   inflating: dataset/train/59/image_05021.jpg
#   inflating: dataset/train/59/image_05022.jpg
#   inflating: dataset/train/59/image_05023.jpg
#   inflating: dataset/train/59/image_05024.jpg
#   inflating: dataset/train/59/image_05025.jpg
#   inflating: dataset/train/59/image_05026.jpg
#   inflating: dataset/train/59/image_05027.jpg
#   inflating: dataset/train/59/image_05028.jpg
#   inflating: dataset/train/59/image_05029.jpg
#   inflating: dataset/train/59/image_05030.jpg
#   inflating: dataset/train/59/image_05031.jpg
#   inflating: dataset/train/59/image_05032.jpg
#   inflating: dataset/train/59/image_05035.jpg
#   inflating: dataset/train/59/image_05036.jpg
#   inflating: dataset/train/59/image_05037.jpg
#   inflating: dataset/train/6/image_07193.jpg
#   inflating: dataset/train/6/image_07194.jpg
#   inflating: dataset/train/6/image_07195.jpg
#   inflating: dataset/train/6/image_07196.jpg
#   inflating: dataset/train/6/image_07197.jpg
#   inflating: dataset/train/6/image_08107.jpg
#   inflating: dataset/train/6/image_08109.jpg
#   inflating: dataset/train/6/image_08110.jpg
#   inflating: dataset/train/6/image_08111.jpg
#   inflating: dataset/train/60/image_02920.jpg
#   inflating: dataset/train/60/image_02921.jpg
#   inflating: dataset/train/60/image_02922.jpg
#   inflating: dataset/train/60/image_02924.jpg
#   inflating: dataset/train/60/image_02925.jpg
#   inflating: dataset/train/60/image_02926.jpg
#   inflating: dataset/train/60/image_02927.jpg
#   inflating: dataset/train/60/image_02929.jpg
#   inflating: dataset/train/60/image_02930.jpg
#   inflating: dataset/train/60/image_02931.jpg
#   inflating: dataset/train/60/image_02934.jpg
#   inflating: dataset/train/60/image_02935.jpg
#   inflating: dataset/train/60/image_02938.jpg
#   inflating: dataset/train/60/image_02939.jpg
#   inflating: dataset/train/60/image_02940.jpg
#   inflating: dataset/train/60/image_02941.jpg
#   inflating: dataset/train/60/image_02942.jpg
#   inflating: dataset/train/60/image_02943.jpg
#   inflating: dataset/train/60/image_02944.jpg
#   inflating: dataset/train/60/image_02945.jpg
#   inflating: dataset/train/60/image_02946.jpg
#   inflating: dataset/train/60/image_02947.jpg
#   inflating: dataset/train/60/image_02949.jpg
#   inflating: dataset/train/60/image_02950.jpg
#   inflating: dataset/train/60/image_02951.jpg
#   inflating: dataset/train/60/image_02952.jpg
#   inflating: dataset/train/60/image_02953.jpg
#   inflating: dataset/train/60/image_02954.jpg
#   inflating: dataset/train/60/image_02955.jpg
#   inflating: dataset/train/60/image_02956.jpg
#   inflating: dataset/train/60/image_02957.jpg
#   inflating: dataset/train/60/image_02960.jpg
#   inflating: dataset/train/60/image_02962.jpg
#   inflating: dataset/train/60/image_02963.jpg
#   inflating: dataset/train/60/image_02964.jpg
#   inflating: dataset/train/60/image_02965.jpg
#   inflating: dataset/train/60/image_02966.jpg
#   inflating: dataset/train/60/image_02967.jpg
#   inflating: dataset/train/60/image_02968.jpg
#   inflating: dataset/train/60/image_02969.jpg
#   inflating: dataset/train/60/image_02970.jpg
#   inflating: dataset/train/60/image_02972.jpg
#   inflating: dataset/train/60/image_02973.jpg
#   inflating: dataset/train/60/image_02975.jpg
#   inflating: dataset/train/60/image_02976.jpg
#   inflating: dataset/train/60/image_02979.jpg
#   inflating: dataset/train/60/image_02980.jpg
#   inflating: dataset/train/60/image_02982.jpg
#   inflating: dataset/train/60/image_02983.jpg
#   inflating: dataset/train/60/image_02984.jpg
#   inflating: dataset/train/60/image_02985.jpg
#   inflating: dataset/train/60/image_02986.jpg
#   inflating: dataset/train/60/image_02988.jpg
#   inflating: dataset/train/60/image_02989.jpg
#   inflating: dataset/train/60/image_02990.jpg
#   inflating: dataset/train/60/image_02991.jpg
#   inflating: dataset/train/60/image_02993.jpg
#   inflating: dataset/train/60/image_02994.jpg
#   inflating: dataset/valid/75/image_02133.jpg
#   inflating: dataset/valid/75/image_02141.jpg
#   inflating: dataset/valid/75/image_02147.jpg
#   inflating: dataset/valid/75/image_02152.jpg
#   inflating: dataset/valid/75/image_02155.jpg
#   inflating: dataset/valid/75/image_02178.jpg
#   inflating: dataset/valid/75/image_02182.jpg
#   inflating: dataset/valid/76/image_02446.jpg
#   inflating: dataset/valid/76/image_02456.jpg
#   inflating: dataset/valid/76/image_02457.jpg
#   inflating: dataset/valid/76/image_02458.jpg
#   inflating: dataset/valid/76/image_02467.jpg
#   inflating: dataset/valid/76/image_02475.jpg
#   inflating: dataset/valid/76/image_02481.jpg
#   inflating: dataset/valid/76/image_02485.jpg
#   inflating: dataset/valid/76/image_02494.jpg
#   inflating: dataset/valid/76/image_02496.jpg
#   inflating: dataset/valid/76/image_02501.jpg
#   inflating: dataset/valid/76/image_02504.jpg
#   inflating: dataset/valid/76/image_02512.jpg
#   inflating: dataset/valid/76/image_02513.jpg
#   inflating: dataset/valid/76/image_02514.jpg
#   inflating: dataset/valid/76/image_02523.jpg
#   inflating: dataset/valid/76/image_02525.jpg
#   inflating: dataset/valid/76/image_02529.jpg
#   inflating: dataset/valid/76/image_02530.jpg
#   inflating: dataset/valid/76/image_02537.jpg
#   inflating: dataset/valid/77/image_00028.jpg
#   inflating: dataset/valid/77/image_00059.jpg
#   inflating: dataset/valid/77/image_00061.jpg
#   inflating: dataset/valid/77/image_00063.jpg
#   inflating: dataset/valid/77/image_00071.jpg
#   inflating: dataset/valid/77/image_00072.jpg
#   inflating: dataset/valid/77/image_00078.jpg
#   inflating: dataset/valid/77/image_00081.jpg
#   inflating: dataset/valid/77/image_00104.jpg
#   inflating: dataset/valid/77/image_00112.jpg
#   inflating: dataset/valid/77/image_00137.jpg
#   inflating: dataset/valid/77/image_00143.jpg
#   inflating: dataset/valid/77/image_00160.jpg
#   inflating: dataset/valid/77/image_00174.jpg
#   inflating: dataset/valid/77/image_00178.jpg
#   inflating: dataset/valid/77/image_00188.jpg
#   inflating: dataset/valid/77/image_00200.jpg
#   inflating: dataset/valid/77/image_00218.jpg
#   inflating: dataset/valid/77/image_00231.jpg
#   inflating: dataset/valid/77/image_00245.jpg
#   inflating: dataset/valid/77/image_00246.jpg
#   inflating: dataset/valid/78/image_01844.jpg
#   inflating: dataset/valid/78/image_01862.jpg
#   inflating: dataset/valid/78/image_01894.jpg
#   inflating: dataset/valid/78/image_01910.jpg
#   inflating: dataset/valid/78/image_01914.jpg
#   inflating: dataset/valid/78/image_01922.jpg
#   inflating: dataset/valid/78/image_01929.jpg
#   inflating: dataset/valid/78/image_01937.jpg
#   inflating: dataset/valid/78/image_01938.jpg
#   inflating: dataset/valid/78/image_01944.jpg
#   inflating: dataset/valid/78/image_01962.jpg
#   inflating: dataset/valid/79/image_06695.jpg
#   inflating: dataset/valid/79/image_06707.jpg
#   inflating: dataset/valid/79/image_06718.jpg
#   inflating: dataset/valid/79/image_06728.jpg
#   inflating: dataset/valid/8/image_03313.jpg
#   inflating: dataset/valid/8/image_03330.jpg
#   inflating: dataset/valid/8/image_03342.jpg
#   inflating: dataset/valid/8/image_03349.jpg
#   inflating: dataset/valid/8/image_03366.jpg
#   inflating: dataset/valid/80/image_01972.jpg
#   inflating: dataset/valid/80/image_01975.jpg
#   inflating: dataset/valid/80/image_01979.jpg
#   inflating: dataset/valid/80/image_01989.jpg
#   inflating: dataset/valid/80/image_01991.jpg
#   inflating: dataset/valid/80/image_01992.jpg
#   inflating: dataset/valid/80/image_02005.jpg
#   inflating: dataset/valid/80/image_02011.jpg
#   inflating: dataset/valid/80/image_02017.jpg
#   inflating: dataset/valid/80/image_02021.jpg
#   inflating: dataset/valid/80/image_02042.jpg
#   inflating: dataset/valid/80/image_02050.jpg
#   inflating: dataset/valid/81/image_00784.jpg
#   inflating: dataset/valid/81/image_00809.jpg
#   inflating: dataset/valid/81/image_00820.jpg
#   inflating: dataset/valid/81/image_00848.jpg
#   inflating: dataset/valid/81/image_00853.jpg
#   inflating: dataset/valid/81/image_00859.jpg
#   inflating: dataset/valid/81/image_00860.jpg
#   inflating: dataset/valid/81/image_00863.jpg
#   inflating: dataset/valid/81/image_00892.jpg
#   inflating: dataset/valid/81/image_00893.jpg
#   inflating: dataset/valid/81/image_00895.jpg
#   inflating: dataset/valid/81/image_00896.jpg
#   inflating: dataset/valid/81/image_00903.jpg
#   inflating: dataset/valid/81/image_00904.jpg
#   inflating: dataset/valid/81/image_00909.jpg
#   inflating: dataset/valid/81/image_00914.jpg
#   inflating: dataset/valid/81/image_00919.jpg
#   inflating: dataset/valid/81/image_00920.jpg
#   inflating: dataset/valid/82/image_01592.jpg
#   inflating: dataset/valid/82/image_01596.jpg
#   inflating: dataset/valid/82/image_01625.jpg
#   inflating: dataset/valid/82/image_01640.jpg
#   inflating: dataset/valid/82/image_01643.jpg
#   inflating: dataset/valid/82/image_01649.jpg
#   inflating: dataset/valid/82/image_01658.jpg
#   inflating: dataset/valid/82/image_01659.jpg
#   inflating: dataset/valid/82/image_01671.jpg
#   inflating: dataset/valid/82/image_01683.jpg
#   inflating: dataset/valid/82/image_01690.jpg
#   inflating: dataset/valid/82/image_01691.jpg
#   inflating: dataset/valid/82/image_01693.jpg
#   inflating: dataset/valid/83/image_01697.jpg
#   inflating: dataset/valid/83/image_01701.jpg
#   inflating: dataset/valid/83/image_01703.jpg
#   inflating: dataset/valid/83/image_01712.jpg
#   inflating: dataset/valid/83/image_01739.jpg
#   inflating: dataset/valid/83/image_01747.jpg
#   inflating: dataset/valid/83/image_01765.jpg
#   inflating: dataset/valid/83/image_01766.jpg
#   inflating: dataset/valid/83/image_01769.jpg
#   inflating: dataset/valid/83/image_01780.jpg
#   inflating: dataset/valid/83/image_01787.jpg
#   inflating: dataset/valid/83/image_01811.jpg
#   inflating: dataset/valid/83/image_01817.jpg
#   inflating: dataset/valid/84/image_02567.jpg
#   inflating: dataset/valid/84/image_02574.jpg
#   inflating: dataset/valid/84/image_02582.jpg
#   inflating: dataset/valid/84/image_02591.jpg
#   inflating: dataset/valid/84/image_02598.jpg
#   inflating: dataset/valid/84/image_02604.jpg
#   inflating: dataset/valid/84/image_02610.jpg
#   inflating: dataset/valid/84/image_02621.jpg
#   inflating: dataset/valid/84/image_02635.jpg
#   inflating: dataset/valid/84/image_02637.jpg
#   inflating: dataset/valid/85/image_04799.jpg
#   inflating: dataset/valid/85/image_04804.jpg
#   inflating: dataset/valid/85/image_04809.jpg
#   inflating: dataset/valid/85/image_04817.jpg
#   inflating: dataset/valid/85/image_04818.jpg
#   inflating: dataset/valid/86/image_02887.jpg
#   inflating: dataset/valid/86/image_02891.jpg
#   inflating: dataset/valid/86/image_02901.jpg
#   inflating: dataset/valid/86/image_02906.jpg
#   inflating: dataset/valid/86/image_02909.jpg
#   inflating: dataset/valid/87/image_05484.jpg
#   inflating: dataset/valid/87/image_05487.jpg
#   inflating: dataset/valid/87/image_05502.jpg
#   inflating: dataset/valid/87/image_05507.jpg
#   inflating: dataset/valid/87/image_05508.jpg
#   inflating: dataset/valid/87/image_05520.jpg
#   inflating: dataset/valid/88/image_00459.jpg
#   inflating: dataset/valid/88/image_00461.jpg
#   inflating: dataset/valid/88/image_00489.jpg
#   inflating: dataset/valid/88/image_00502.jpg
#   inflating: dataset/valid/88/image_00508.jpg
#   inflating: dataset/valid/88/image_00509.jpg
#   inflating: dataset/valid/88/image_00512.jpg
#   inflating: dataset/valid/88/image_00516.jpg
#   inflating: dataset/valid/88/image_00518.jpg
#   inflating: dataset/valid/88/image_00531.jpg
#   inflating: dataset/valid/88/image_00533.jpg
#   inflating: dataset/valid/88/image_00539.jpg
#   inflating: dataset/valid/88/image_00542.jpg
#   inflating: dataset/valid/88/image_00544.jpg
#   inflating: dataset/valid/88/image_00545.jpg
#   inflating: dataset/valid/88/image_00546.jpg
#   inflating: dataset/valid/88/image_00547.jpg
#   inflating: dataset/valid/88/image_00554.jpg
#   inflating: dataset/valid/88/image_00556.jpg
#   inflating: dataset/valid/88/image_00574.jpg
#   inflating: dataset/valid/88/image_00577.jpg
#   inflating: dataset/valid/88/image_00585.jpg
#   inflating: dataset/valid/88/image_00593.jpg
#   inflating: dataset/valid/88/image_00595.jpg
#   inflating: dataset/valid/88/image_00597.jpg
#   inflating: dataset/valid/89/image_00623.jpg
#   inflating: dataset/valid/89/image_00624.jpg
#   inflating: dataset/valid/89/image_00627.jpg
#   inflating: dataset/valid/89/image_00640.jpg
#   inflating: dataset/valid/89/image_00652.jpg
#   inflating: dataset/valid/89/image_00691.jpg
#   inflating: dataset/valid/89/image_00692.jpg
#   inflating: dataset/valid/89/image_00696.jpg
#   inflating: dataset/valid/89/image_00730.jpg
#   inflating: dataset/valid/89/image_00741.jpg
#   inflating: dataset/valid/89/image_00746.jpg
#   inflating: dataset/valid/89/image_00749.jpg
#   inflating: dataset/valid/89/image_00752.jpg
#   inflating: dataset/valid/89/image_00759.jpg
#   inflating: dataset/valid/89/image_00763.jpg
#   inflating: dataset/valid/89/image_00764.jpg
#   inflating: dataset/valid/9/image_06398.jpg
#   inflating: dataset/valid/9/image_06414.jpg
#   inflating: dataset/valid/98/image_07757.jpg
#   inflating: dataset/valid/98/image_07764.jpg
#   inflating: dataset/valid/98/image_07766.jpg
#   inflating: dataset/valid/98/image_07769.jpg
#   inflating: dataset/valid/98/image_07778.jpg
#   inflating: dataset/valid/98/image_07792.jpg
#   inflating: dataset/valid/98/image_07796.jpg
#   inflating: dataset/valid/98/image_07810.jpg
#   inflating: dataset/valid/98/image_07820.jpg
#   inflating: dataset/valid/98/image_07827.jpg
#   inflating: dataset/valid/99/image_07860.jpg
#   inflating: dataset/valid/99/image_07862.jpg
#   inflating: dataset/valid/99/image_07869.jpg
#   inflating: dataset/valid/99/image_07873.jpg
#   inflating: dataset/valid/99/image_07875.jpg
#   inflating: dataset/valid/99/image_08063.jpg
#   inflating: sample_submission.csv

# %%
import tensorflow as tf
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/dataset",
    labels = None,
    image_size = (64,64),
    batch_size = None,
    shuffle = True,
    seed = 42,
    interpolation = "bilinear")
# Out:
# Found 8189 files belonging to 1 classes.

# %%
def preprocess(img):
  img = (tf.cast(img, "float32") - 127.5)/ 127.5
  return img

train = train_data.map(lambda x: preprocess(x))
train = train.repeat(5)
train = train.batch(64, drop_remainder = True)

# %% [markdown]
# **Diffusion Schedules**

# %%
import math
def offset_cosine_diffusion_schedule(diffusion_times):
  min_signal_rate = 0.02
  max_signal_rate = 0.95
  start_angle = tf.acos(max_signal_rate)
  end_angle = tf.acos(min_signal_rate)

  diffusion_angles = start_angle + diffusion_times * (end_angle - start_angle)

  signal_rates = tf.cos(diffusion_angles)
  noise_rates = tf.sin(diffusion_angles)

  return noise_rates, signal_rates

def cosine_diffusion_schedule(diffusion_times):
  signal_rates = tf.cos(diffusion_times * math.pi*2)
  noise_rates = tf.sin(diffusion_times * math.pi / 2)
  return noise_rates, signal_rates

# %% [markdown]
# **Build Model**

# %%
IMAGE_SIZE = 64
BATCH_SIZE = 64
DATASET_REPETITIONS = 5
LOAD_MODEL = False

NOISE_EMBEDDING_SIZE = 32
PLOT_DIFFUSION_STEPS = 20

# optimization
EMA = 0.999
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-4
EPOCHS = 50

# %%
def sinusoidal_embedding(x):
    frequencies = tf.exp(
        tf.linspace(
            tf.math.log(1.0),
            tf.math.log(1000.0),
            NOISE_EMBEDDING_SIZE // 2,
        )
    )
    angular_speeds = 2.0 * math.pi * frequencies
    embeddings = tf.concat(
        [tf.sin(angular_speeds * x), tf.cos(angular_speeds * x)], axis=3
    )
    return embeddings

# %% [markdown]
# Define ResidualBlock, DownBlock and UpBlock for Unet

# %%
def ResidualBlock(width):
    def apply(x):
        input_width = x.shape[3]
        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(width, kernel_size=1)(x)
        x = layers.BatchNormalization(center=False, scale=False)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", activation="swish"
        )(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same")(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownBlock(width, block_depth):
    def apply(x):
        x, skips = x
        for _ in range(block_depth):
            x = ResidualBlock(width)(x)
            skips.append(x)
        x = layers.AveragePooling2D(pool_size=2)(x)
        return x

    return apply


def UpBlock(width, block_depth):
    def apply(x):
        x, skips = x
        x = layers.UpSampling2D(size=2, interpolation="bilinear")(x)
        for _ in range(block_depth):
            x = layers.Concatenate()([x, skips.pop()])
            x = ResidualBlock(width)(x)
        return x

    return apply

# %% [markdown]
# Build Unet

# %%
from tensorflow.keras import layers, models
noisy_images = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
x = layers.Conv2D(32, kernel_size=1)(noisy_images)

noise_variances = layers.Input(shape=(1, 1, 1))
noise_embedding = layers.Lambda(sinusoidal_embedding)(noise_variances)
noise_embedding = layers.UpSampling2D(size=IMAGE_SIZE, interpolation="nearest")(
    noise_embedding
)

x = layers.Concatenate()([x, noise_embedding])

skips = []

x = DownBlock(32, block_depth=2)([x, skips])
x = DownBlock(64, block_depth=2)([x, skips])
x = DownBlock(96, block_depth=2)([x, skips])

x = ResidualBlock(128)(x)
x = ResidualBlock(128)(x)

x = UpBlock(96, block_depth=2)([x, skips])
x = UpBlock(64, block_depth=2)([x, skips])
x = UpBlock(32, block_depth=2)([x, skips])

x = layers.Conv2D(3, kernel_size=1, kernel_initializer="zeros")(x)

unet = models.Model([noisy_images, noise_variances], x, name="unet")

# %%
# from tensorflow.keras import metrics, losses
# class DiffusionModel(models.Model):
#   def __init__(self):
#     super().__init__()
#     self.normalizer=  layers.Normalization()
#     self.network = unet
#     self.ema_network = models.clone_model(self.network)
#     self.diffusion_schedule = offset_cosine_diffusion_schedule

#   def compile(self, **kwargs):
#     super().compile(**kwargs)
#     self.noise_loss_tracker = metrics.Mean(name="n_loss")

#   @property
#   def metrics(self):
#     return [self.noise_loss_tracker]

#   def denormalize(self, images):
#       images = self.normalizer.mean + images * self.normalizer.variance**0.5
#       return tf.clip_by_value(images, 0.0, 1.0)

#   def denoise(self, noisy_images, noise_rates, signal_rates, training):
#     if training:
#       network = self.network
#     else:
#       network = self.ema_network
#     pred_noises = network([noisy_images, noise_rates**2], training = training)
#     pred_images = (noisy_images - noise_rates * pred_noises) / signal_rates

#     return pred_noises, pred_images

#     def reverse_diffusion(self, initial_noise, diffusion_steps):
#       num_images = initial_noise.shape[0]
#       step_size = 1.0 / diffusion_steps
#       current_images = initial_noise
#       for step in range(diffusion_steps):
#           diffusion_times = tf.ones((num_images, 1, 1, 1)) - step * step_size
#           noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
#           pred_noises, pred_images = self.denoise(
#               current_images, noise_rates, signal_rates, training=False
#           )
#           next_diffusion_times = diffusion_times - step_size
#           next_noise_rates, next_signal_rates = self.diffusion_schedule(
#               next_diffusion_times
#           )
#           current_images = (
#               next_signal_rates * pred_images + next_noise_rates * pred_noises
#           )
#       return pred_images

#     def generate(self, num_images, diffusion_steps, initial_noise=None):
#       if initial_noise is None:
#           initial_noise = tf.random.normal(
#               shape=(num_images, IMAGE_SIZE, IMAGE_SIZE, 3)
#           )
#       generated_images = self.reverse_diffusion(
#           initial_noise, diffusion_steps
#       )
#       generated_images = self.denormalize(generated_images)
#       return generated_images

#   def train_step(self, images):
#     images = self.normalizer(images, training = True)
#     noises = tf.random.normal(shape = tf.shape(images))
#     batch_size = tf.shape(images)[0]
#     diffusion_times = tf.random.uniform(shape = (batch_size, 1, 1, 1), minval=0.0, maxval = 1.0)
#     noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
#     noisy_images = signal_rates*images + noise_rates * noises

#     with tf.GradientTape() as tape:
#       pred_noises, pred_images = self.denoise(noisy_images, noise_rates, signal_rates, training = True)
#       noise_loss = self.loss(noises, pred_noises)

#     gradients = tape.gradient(noise_loss, self.network.trainable_weights)
#     self.optimizer.apply_gradients(
#         zip(gradients, self.network.trainiable_weights)
#     )
#     self.noise_loss_tracker.update_state(noise_loss)

#     for weight, ema_weight in zip(
#         self.network.weights, self.ema_network.weights
#     ):
#       ema_weight.assign(0.999 * ema_weight + (1 - 0.9990) * weight)

#     return {m.name: m.result() for m in self.metrics}

# %%
class DiffusionModel(models.Model):
    def __init__(self):
        super().__init__()

        self.normalizer = layers.Normalization()
        self.network = unet
        self.ema_network = models.clone_model(self.network)
        self.diffusion_schedule = offset_cosine_diffusion_schedule

    def compile(self, **kwargs):
        super().compile(**kwargs)
        self.noise_loss_tracker = metrics.Mean(name="n_loss")

    @property
    def metrics(self):
        return [self.noise_loss_tracker]

    def denormalize(self, images):
        images = self.normalizer.mean + images * self.normalizer.variance**0.5
        return tf.clip_by_value(images, 0.0, 1.0)

    def denoise(self, noisy_images, noise_rates, signal_rates, training):
        if training:
            network = self.network
        else:
            network = self.ema_network
        pred_noises = network(
            [noisy_images, noise_rates**2], training=training
        )
        pred_images = (noisy_images - noise_rates * pred_noises) / signal_rates

        return pred_noises, pred_images

    def reverse_diffusion(self, initial_noise, diffusion_steps):
        num_images = initial_noise.shape[0]
        step_size = 1.0 / diffusion_steps
        current_images = initial_noise
        for step in range(diffusion_steps):
            diffusion_times = tf.ones((num_images, 1, 1, 1)) - step * step_size
            noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
            pred_noises, pred_images = self.denoise(
                current_images, noise_rates, signal_rates, training=False
            )
            next_diffusion_times = diffusion_times - step_size
            next_noise_rates, next_signal_rates = self.diffusion_schedule(
                next_diffusion_times
            )
            current_images = (
                next_signal_rates * pred_images + next_noise_rates * pred_noises
            )
        return pred_images

    def generate(self, num_images, diffusion_steps, initial_noise=None):
        if initial_noise is None:
            initial_noise = tf.random.normal(
                shape=(num_images, IMAGE_SIZE, IMAGE_SIZE, 3)
            )
        generated_images = self.reverse_diffusion(
            initial_noise, diffusion_steps
        )
        generated_images = self.denormalize(generated_images)
        return generated_images

    def train_step(self, images):
        images = self.normalizer(images, training=True)
        noises = tf.random.normal(shape=(BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3))

        diffusion_times = tf.random.uniform(
            shape=(BATCH_SIZE, 1, 1, 1), minval=0.0, maxval=1.0
        )
        noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)

        noisy_images = signal_rates * images + noise_rates * noises

        with tf.GradientTape() as tape:
            # train the network to separate noisy images to their components
            pred_noises, pred_images = self.denoise(
                noisy_images, noise_rates, signal_rates, training=True
            )

            noise_loss = self.loss(noises, pred_noises)  # used for training

        gradients = tape.gradient(noise_loss, self.network.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.network.trainable_weights)
        )

        self.noise_loss_tracker.update_state(noise_loss)

        for weight, ema_weight in zip(
            self.network.weights, self.ema_network.weights
        ):
            ema_weight.assign(EMA * ema_weight + (1 - EMA) * weight)

        return {m.name: m.result() for m in self.metrics}

# %%
ddm = DiffusionModel()
ddm.normalizer.adapt(train)

# %%
from tensorflow.keras import metrics, losses
ddm.compile(
    optimizer=tf.keras.optimizers.experimental.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    ),
    loss=losses.mean_absolute_error,
)

ddm.fit(train, epochs = 100)
# Out:
# Epoch 1/100
# 639/639 [==============================] - 143s 195ms/step - n_loss: 0.1784
# Epoch 2/100
# 639/639 [==============================] - 124s 192ms/step - n_loss: 0.1772
# Epoch 3/100
# 639/639 [==============================] - 126s 194ms/step - n_loss: 0.1763
# Epoch 4/100
# 639/639 [==============================] - 124s 191ms/step - n_loss: 0.1759
# Epoch 5/100
# 639/639 [==============================] - 126s 195ms/step - n_loss: 0.1759
# Epoch 6/100
# 639/639 [==============================] - 125s 194ms/step - n_loss: 0.1758
# Epoch 7/100
# 639/639 [==============================] - 126s 195ms/step - n_loss: 0.1752
# Epoch 8/100
# 639/639 [==============================] - 125s 194ms/step - n_loss: 0.1754
# Epoch 9/100
# 639/639 [==============================] - 125s 193ms/step - n_loss: 0.1751
# Epoch 10/100
# 639/639 [==============================] - 125s 193ms/step - n_loss: 0.1746
# Epoch 11/100
# 639/639 [==============================] - 125s 194ms/step - n_loss: 0.1742
# Epoch 12/100
# 639/639 [==============================] - 124s 192ms/step - n_loss: 0.1744
# Epoch 13/100
# 639/639 [==============================] - 123s 191ms/step - n_loss: 0.1748
# Epoch 14/100
# 639/639 [==============================] - 125s 194ms/step - n_loss: 0.1731
# Epoch 15/100
# 639/639 [==============================] - 125s 194ms/step - n_loss: 0.1736

# %% [markdown]
# **Inference**

# %%
import matplotlib.pyplot as plt
def display(
    images, n=10, size=(20, 3), cmap="gray_r", as_type="float32", save_to=None
):
    """
    Displays n random images from each one of the supplied arrays.
    """
    if images.max() > 1.0:
        images = images / 255.0
    elif images.min() < 0.0:
        images = (images + 1.0) / 2.0

    plt.figure(figsize=size)
    for i in range(n):
        _ = plt.subplot(1, n, i + 1)
        plt.imshow(images[i].astype(as_type), cmap=cmap)
        plt.axis("off")

    if save_to:
        plt.savefig(save_to)
        print(f"\nSaved to {save_to}")

    plt.show()

# %%
generated_images = ddm.generate(num_images=10, diffusion_steps=20).numpy()
display(generated_images)

# %%
# View improvement over greater number of diffusion steps
import numpy as np
for diffusion_steps in list(np.arange(1, 6, 1)) + [20] + [100]:
    tf.random.set_seed(42)
    generated_images = ddm.generate(
        num_images=10,
        diffusion_steps=diffusion_steps,
    ).numpy()
    display(generated_images)

# %%
tf.random.set_seed(100)


def spherical_interpolation(a, b, t):
    return np.sin(t * math.pi / 2) * a + np.cos(t * math.pi / 2) * b


for i in range(5):
    a = tf.random.normal(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    b = tf.random.normal(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    initial_noise = np.array(
        [spherical_interpolation(a, b, t) for t in np.arange(0, 1.1, 0.1)]
    )
    generated_images = ddm.generate(
        num_images=2, diffusion_steps=20, initial_noise=initial_noise
    ).numpy()
    display(generated_images, n=11)
